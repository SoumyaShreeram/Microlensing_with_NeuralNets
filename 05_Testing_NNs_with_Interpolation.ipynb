# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaShreeram/Microlensing_with_NeuralNets/blob/master/05_Testing_NNs_with_Interpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Testing Neural Network Architecture
#
# The following notebook tests NNs using the light-curves that are
#   - Linearly intrapolated
#   - use Gaussian process intropolation
#
# The model is trained, tested, and evaluated.
#
# Author: Soumya Shreeram <br>
# Script adapted from: Millon Martin & Kevin Müller <br>
# Date: 23rd February 2020

# %% [markdown]
# Import all required python libraries

# %%
from google.colab import drive
import os
import pickle
import importlib
import itertools

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import random
import os
from IPython.display import Image, SVG

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from scipy.interpolate import interp1d 

# %tensorflow_version 1.x
import tensorflow as tf

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, InputSpec
from tensorflow.python.keras.layers import Conv1D, Conv2D
from tensorflow.python.keras.layers import MaxPooling1D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Add, BatchNormalization, Concatenate
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Mount google drive

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Directory where the `python` files are stored on Google Drive. These imported files are also available in `.ipynb` format on the GitHub repo with same names (without the dr; <strike>`dr`</strike>`0X_sameFileName`). dr stands for drive.

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks')

import nb_02i_preprocessing_data as dat
import nb_03_neural_network_designs as nnet

# %% [markdown]
# Setting up the path to the data directory

# %%
current_dir = os.getcwd()
data_dir = '/content/gdrive/My Drive/training_set_microlensing/'
save_image_dir = r'/content/gdrive/My Drive/Colab Notebooks/Images/'
save_model_dir = r'/content/gdrive/My Drive/Colab Notebooks/Models/'

# %% [markdown]
# ### 1. Input parameters

# %%
v_t = [500, 300] # transverse velcity
v_t_idx = 0 # choose index value for the velocity you would like (0 or 1)
r_0 = (2,4,10,15,20,30,40,60,80,100) # scale radius
output_class_names = [str(r) for r in r_0 ]

# select type of Interpolation
cubic, linear = False, True

# reloads the file if any changes are made in the methods
importlib.reload(dat)
# Out:
# <module 'nb_02i_preprocessing_data' from '/content/gdrive/My Drive/Colab Notebooks/nb_02i_preprocessing_data.py'>

# %% [markdown]
# ### 2. Load the data

# %% [markdown]
# There are 10 categories into which the light-curves are classified. Each category is represented by the scale radius `r_0`. For every scale radius, there exists a light-curve whose data points are stored in the 3D array `l_curves`.

# %%
# sets the sampling parameters
sample_params = dat.setSamplingParameters(v_t[v_t_idx], data_dir, euler_sampling=True)

# initializes data arrays
class_cat, l_curves, out_catergories, out_radii = dat.initializer(r_0, sample_params)

for i, rad in enumerate(r_0):
  filename = dat.getFilename(data_dir, rad, v_t[v_t_idx], sample_params)
  
  # load data from the file
  l_curves, mjhd, err_mag_ml = dat.loadData(filename, l_curves, sample_params, i)
  out_catergories[i*sample_params[0]:(i+1)*sample_params[0]] = class_cat[1][i]
  out_radii[i*sample_params[0]:(i+1)*sample_params[0]] = r_0[i]

# %% [markdown]
# #### 2.1 Interpolation of the light curves

# %%
def interpolateLCurves(l_curves, mjhd, l_curves_interpolated, type_inter='linear'):
  """
  Function for interpolating the light curves 'linearly'
  @l_curves :: non-interpolated light curves 3Darray
  @l_curves_interpolated :: empty array with shape same as l_curves

  @Returns:: linearly interpolated light curves 3Darray
  """
  for i in range(len(l_curves)):
    # x array of times
    x = mjhd
    y = l_curves[i, :, 0]
    
    # interpolation
    f = interp1d(x,y, kind=type_inter)
    
    # capturing the features using y_inter
    xnew = np.linspace(x[0], x[-1], num=len(mjhd))
    y_inter = f(xnew)

    # setting the shape same as that on l_curves array
    y_inter.shape = (len(y_inter), 1)
    l_curves_interpolated = np.append(l_curves_interpolated, [y_inter], axis=0)
  return l_curves_interpolated, xnew

# %%
linear, cubic = False, True
l_curves_interpolated = np.array([])
l_curves_interpolated.shape = (0, len(l_curves[0,:,0]),1)

# linear/cubic interpolated the light curves
if linear:
  lc_inter_linear, mjhd_inter = interpolateLCurves(l_curves, mjhd, l_curves_interpolated, \
                                       type_inter='linear')
  
if cubic:
  lc_inter_cubic, mjhd_inter = interpolateLCurves(l_curves, mjhd, l_curves_interpolated, \
                                      type_inter='cubic')

# %% [markdown]
# #### 2.1 Plots of some random light-curves

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))
n = [100, 26]
colors = ['#127a00',  '#00727a', '#888894',]

for i, num in enumerate(n):
  # light curves with cubic interpolation
  ax.plot(mjhd_inter, lc_inter_cubic[n[i], :, 0], '.', color='r', label='Cubic interpolation', markersize=4)

  # light curves with linear interpolation
  ax.plot(mjhd_inter, lc_inter_linear[n[i], :, 0], '.', color='k', label='Linear interpolation', markersize=2)

  # without interpolation
  ax.plot(mjhd, l_curves[n[i], :], '.', color=colors[i], label='Light Curve %i'%(n[i]), markersize=8)

dat.setLabels(ax, 'HJD (days)', 'Magnitude', ticks=True, legend=True)
fig.savefig(save_image_dir+'/interpolated_lcurves.png')

# %% [markdown]
# ### 3. Generate training and testing data sets

# %%
train_l_curves, test_l_curves, data_sets, onehot_train, \
onehot_test = dat.generateTestTrain(lc_inter_linear, out_catergories, \
                                    out_radii, r_0)

# %% [markdown]
# ### 4. Compiling the 3 networks
#
# The three networks compiled here are coded in `04_Neural_Network_Designs.ipynb` that have been saved as `dr04_Neural_Network_Designs.py`, for ease of importing it. The python files can be found in the GitHub repo folder *python files*.
#
# Note that if you are running this from colab, need to have these `.py` files in your drive folder *Colab Notebooks*.

# %% [markdown]
# Default constants that can be modified.

# %%
# choose which network to use (default CNN2)
CNN1, CNN2, ResNet = False, False, True

model_types = [CNN1, CNN2, ResNet]
model_name_list = ['CNN1','CNN2','ResNet']

for i in range(len(model_name_list)):
  if model_types[i]:
    model_name = model_name_list[i]
print('Using the Neural Network:', model_name)
# Out:
# Using the Neural Network: ResNet

# %% [markdown]
# The following code block uses the methods defined in the file `dr04_Neural_Network_Designs.py`: imported as **`nnet`**
#
# Model parameters are defined in the methods in **`nnet`** additionally some more details:
# * `num_hidden_nodes`: number of nodes in hidden fully connected layer
# *`dropout_ratio`: % of nodes in the hidden layer to dropout during back-propagation update of the network weights

# %% [markdown]
# #### 4.1 Compiling CNN2

# %%
if CNN2:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  """--- CNN2 Model Parameters ---"""
  num_filter = (32, 32, 44, 44)
  kern_size = (21,21,15,15)
  maxpoolsize = (None, 15, None, 15)
  shortcut_link = (0,1,2,3)
  batch_norm = False
  num_hidden_nodes = [1500]
  dropout_ratio = 0.4  
  sampling = 3
  num_pieces = 1
  
  # prepare the data
  data_prep = nnet.prepareDataSampleCuts(test_l_curves, sampling, num_pieces)

  # build the model
  inputs, outputs = nnet.buildModelCNN2(sample_params[2], num_filter, kern_size, \
                                        maxpoolsize, num_hidden_nodes,\
                                        dropout_ratio, shortcut_link, batch_norm, \
                                        data_prep.shape[1], r_0)

  # compile the model
  # optimisation algorithm, loss (cost) function
  optimizer_type = Adam(lr=5e-4)  
  loss = 'categorical_crossentropy'  
  #accuracy metric to be determined after each epoch 
  metrics = ['categorical_accuracy'] 

  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                    metrics, save_image_dir+'CNN2', True)

  print('Network created')

# %% [markdown]
# #### 4.2 Compiling ResNet

# %%
if ResNet:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  """--- ResNet Model Parameters ---"""
  num_filter = (32, 32, 32)
  kern_size = (10,20,50)
  n_block = 5
  maxpoolsize = 3
  num_hidden_nodes =[1000.0,]
  dropout_ratio = 0.7 
  batch_norm = True
  #If they are not 1, this network is not correctly defined.
  sampling = 1
  num_pieces = 1

  # build network
  inputs, outputs = nnet.defineResnet(sample_params[2], num_filter, \
                                           kern_size, n_block,maxpoolsize,\
                                           num_hidden_nodes, dropout_ratio, r_0,\
                                           batch_norm = batch_norm)
  
  learning_rate = 1e-4
  decay_rate = 0.0
  optimizer_type = Adam(lr=learning_rate, decay = decay_rate)  
  loss = 'categorical_crossentropy'  
  metrics = ['categorical_accuracy'] 

  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                     metrics,save_image_dir+'ResNet', True)
  
  #model.load_weights('/content/gdrive/My Drive/Colab_Notebooks/Deep_learning_for_optical_IMaging/Resnet_weights.h5')

  print('Network created')
# Out:
# WARNING:tensorflow:Entity <bound method GlobalMaxPoolingSp2D.call of <nb_03_neural_network_designs.GlobalMaxPoolingSp2D object at 0x7f6689ee6128>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method GlobalMaxPoolingSp2D.call of <nb_03_neural_network_designs.GlobalMaxPoolingSp2D object at 0x7f6689ee6128>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 955, None, 1 0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 955, None, 32 352         input_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 955, None, 32 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 955, None, 32 20512       activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 955, None, 32 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 955, None, 32 51232       activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 955, None, 32 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 955, None, 32 0           activation_12[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 477, None, 32 0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 477, None, 32 128         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 477, None, 32 10272       batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 477, None, 32 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 477, None, 32 20512       activation_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 477, None, 32 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 477, None, 32 51232       activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 477, None, 32 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 477, None, 32 0           activation_15[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 238, None, 32 0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 238, None, 32 128         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 238, None, 32 10272       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 238, None, 32 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 238, None, 32 20512       activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 238, None, 32 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 238, None, 32 51232       activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 238, None, 32 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 238, None, 32 0           activation_18[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 118, None, 32 0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 118, None, 32 128         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 118, None, 32 10272       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 118, None, 32 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 118, None, 32 20512       activation_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 118, None, 32 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 118, None, 32 51232       activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 118, None, 32 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 118, None, 32 0           activation_21[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 58, None, 32) 0           add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 58, None, 32) 128         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 58, None, 32) 10272       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 58, None, 32) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 58, None, 32) 20512       activation_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 58, None, 32) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 58, None, 32) 51232       activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 58, None, 32) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 58, None, 32) 0           activation_24[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 28, None, 32) 0           add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, None, 32) 128         max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# global_max_pooling_sp2d_1 (Glob (None, 28, 32)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 896)          0           global_max_pooling_sp2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1000)         897000      flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 1000)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1000)         0           activation_25[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           10010       dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 10)           0           dense_3[0][0]
# ==================================================================================================
# Total params: 1,307,810
# Trainable params: 1,307,490
# Non-trainable params: 320
# __________________________________________________________________________________________________
# None
# Network created

# %% [markdown]
# ### 5. Training the network
#
# Constants used for training the network

# %%
validtrain_split_ratio = 0.2  # % of the seen dataset to be put aside for validation, rest is for training
max_epochs = 30  # maxmimum number of epochs to be iterated
batch_size = 60   # batch size for the training data set
num_inputs = 1

# %%
if sampling == 1 and num_pieces == 1:
  model, history = nnet.fit_model_generator(model, train_l_curves, onehot_train, \
                    num_inputs = num_inputs, batch_size = batch_size, \
                    epochs = max_epochs, validation_split = validtrain_split_ratio, \
                    verbose = 1)
else:
  data_prep = nnet.prepareDataSampleCuts(train_l_curves, sampling, num_pieces)

  model, history = nnet.fit_model_generator(model, data_prep, onehot_train, \
                    num_inputs = num_inputs, batch_size = batch_size, \
                    epochs = max_epochs, validation_split = validtrain_split_ratio, \
                    verbose = 1)
  
print('Training completed')
# Out:
# Train on 6400 samples, validate on 1600 samples
# Epoch 1/30
# 6400/6400 [==============================] - 108s 17ms/sample - loss: 2.8318 - categorical_accuracy: 0.0956 - val_loss: 2.3168 - val_categorical_accuracy: 0.1025
# Epoch 2/30
# 6400/6400 [==============================] - 110s 17ms/sample - loss: 2.6415 - categorical_accuracy: 0.1044 - val_loss: 2.3061 - val_categorical_accuracy: 0.1031
# Epoch 3/30
# 6400/6400 [==============================] - 111s 17ms/sample - loss: 2.4205 - categorical_accuracy: 0.1108 - val_loss: 2.2980 - val_categorical_accuracy: 0.1125
# Epoch 4/30
# 6400/6400 [==============================] - 109s 17ms/sample - loss: 2.3439 - categorical_accuracy: 0.1195 - val_loss: 2.2784 - val_categorical_accuracy: 0.1206
# Epoch 5/30
# 6400/6400 [==============================] - 111s 17ms/sample - loss: 2.3064 - categorical_accuracy: 0.1202 - val_loss: 2.2764 - val_categorical_accuracy: 0.1200
# Epoch 6/30
# 6400/6400 [==============================] - 108s 17ms/sample - loss: 2.2730 - categorical_accuracy: 0.1389 - val_loss: 2.2449 - val_categorical_accuracy: 0.1269
# Epoch 7/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.2448 - categorical_accuracy: 0.1431 - val_loss: 2.2315 - val_categorical_accuracy: 0.1425
# Epoch 8/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.2245 - categorical_accuracy: 0.1484 - val_loss: 2.1985 - val_categorical_accuracy: 0.1488
# Epoch 9/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.2089 - categorical_accuracy: 0.1541 - val_loss: 2.2024 - val_categorical_accuracy: 0.1531
# Epoch 10/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.1906 - categorical_accuracy: 0.1603 - val_loss: 2.1809 - val_categorical_accuracy: 0.1456
# Epoch 11/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.1860 - categorical_accuracy: 0.1614 - val_loss: 2.1857 - val_categorical_accuracy: 0.1525
# Epoch 12/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.1754 - categorical_accuracy: 0.1647 - val_loss: 2.2193 - val_categorical_accuracy: 0.1150
# Epoch 13/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.1656 - categorical_accuracy: 0.1723 - val_loss: 2.1782 - val_categorical_accuracy: 0.1412
# Epoch 14/30
# 6400/6400 [==============================] - 110s 17ms/sample - loss: 2.1624 - categorical_accuracy: 0.1669 - val_loss: 2.1796 - val_categorical_accuracy: 0.1444
# Epoch 15/30
# 6400/6400 [==============================] - 109s 17ms/sample - loss: 2.1533 - categorical_accuracy: 0.1758 - val_loss: 2.1855 - val_categorical_accuracy: 0.1650
# Epoch 16/30
# 6400/6400 [==============================] - 107s 17ms/sample - loss: 2.1502 - categorical_accuracy: 0.1747 - val_loss: 2.1712 - val_categorical_accuracy: 0.1481
# Epoch 17/30
# 6400/6400 [==============================] - 107s 17ms/sample - loss: 2.1442 - categorical_accuracy: 0.1720 - val_loss: 2.1628 - val_categorical_accuracy: 0.1425
# Epoch 18/30
# 6400/6400 [==============================] - 107s 17ms/sample - loss: 2.1357 - categorical_accuracy: 0.1761 - val_loss: 2.1691 - val_categorical_accuracy: 0.1462
# Epoch 19/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.1273 - categorical_accuracy: 0.1758 - val_loss: 2.1892 - val_categorical_accuracy: 0.1550
# Epoch 20/30
# 6400/6400 [==============================] - 112s 17ms/sample - loss: 2.1111 - categorical_accuracy: 0.1816 - val_loss: 2.1389 - val_categorical_accuracy: 0.1606
# Epoch 21/30
# 6400/6400 [==============================] - 107s 17ms/sample - loss: 2.1087 - categorical_accuracy: 0.1877 - val_loss: 2.1582 - val_categorical_accuracy: 0.1581
# Epoch 22/30
# 6400/6400 [==============================] - 107s 17ms/sample - loss: 2.1011 - categorical_accuracy: 0.1931 - val_loss: 2.1470 - val_categorical_accuracy: 0.1612
# Epoch 23/30
# 6400/6400 [==============================] - 106s 17ms/sample - loss: 2.0981 - categorical_accuracy: 0.1895 - val_loss: 2.1335 - val_categorical_accuracy: 0.1644
# Epoch 24/30
# 6400/6400 [==============================] - 103s 16ms/sample - loss: 2.0971 - categorical_accuracy: 0.1912 - val_loss: 2.1342 - val_categorical_accuracy: 0.1544
# Epoch 25/30
# 6400/6400 [==============================] - 100s 16ms/sample - loss: 2.0763 - categorical_accuracy: 0.1969 - val_loss: 2.2117 - val_categorical_accuracy: 0.1506
# Epoch 26/30
# 6400/6400 [==============================] - 100s 16ms/sample - loss: 2.0776 - categorical_accuracy: 0.2027 - val_loss: 2.1468 - val_categorical_accuracy: 0.1781
# Epoch 27/30
# 6400/6400 [==============================] - 101s 16ms/sample - loss: 2.0659 - categorical_accuracy: 0.2023 - val_loss: 2.1605 - val_categorical_accuracy: 0.1713
# Epoch 28/30
# 6400/6400 [==============================] - 100s 16ms/sample - loss: 2.0603 - categorical_accuracy: 0.2031 - val_loss: 2.1157 - val_categorical_accuracy: 0.1625
# Epoch 29/30
# 6400/6400 [==============================] - 100s 16ms/sample - loss: 2.0571 - categorical_accuracy: 0.2109 - val_loss: 2.2045 - val_categorical_accuracy: 0.1550
# Epoch 30/30
# 6400/6400 [==============================] - 100s 16ms/sample - loss: 2.0503 - categorical_accuracy: 0.2100 - val_loss: 2.1305 - val_categorical_accuracy: 0.1669
# Training completed

# %%
# plots the history
fig, ax = plt.subplots(1,2, figsize=(14,6))
labels = ['training', 'validation']
loss_Accuracy = ['loss', 'val_loss', 'categorical_accuracy', 'val_categorical_accuracy']

model_history = history.history
dat.plotLoss(ax[0], model_history, loss_Accuracy, model_name, labels)
dat.plotAccuracy(ax[1], model_history, loss_Accuracy, model_name, labels)
 
fig.savefig(save_image_dir+'/LandA_inter%s_epochs_%d.png'%(model_name, max_epochs))    
fig.tight_layout()

# %% [markdown]
# ### 6. Displaying the classification report, confusion matrix

# %%
def evaluateAndPredict(model, test_l_curves, onehot_test, num_inputs):
  """
  Function evaluated the models and preducts the results
  @test_l_curves :: test data (arguments-> data_prep for CNN2)
  """
  evaluate_res = nnet.evaluate_model(model, test_l_curves, onehot_test, \
                                num_inputs = num_inputs, verbose = 1)

  print(evaluate_res[1])

  output_predict_onehot, output_ref_onehot = nnet.predict_model(model, test_l_curves, \
                                                                onehot_test, \
                                                                num_inputs = num_inputs, \
                                                                verbose = 1)
  return output_predict_onehot, output_ref_onehot

# %%
# prepare data with sample cuts and evaluate residuals
if CNN2:
  data_prep = nnet.prepareDataSampleCuts(test_l_curves, sampling, num_pieces)
  output_predict_onehot, output_ref_onehot = evaluateAndPredict(model, \
                                                                data_prep, \
                                                                onehot_test, \
                                                                num_inputs)
if ResNet:
  output_predict_onehot, output_ref_onehot = evaluateAndPredict(model, \
                                                                test_l_curves, \
                                                                onehot_test, \
                                                                num_inputs)
output_predict_c = np.argmax(output_predict_onehot, axis=1)
output_ref_c = np.argmax(output_ref_onehot, axis=1)

print('Test set classification report:\n')
print(classification_report(output_ref_c, output_predict_c,  \
                            target_names=output_class_names))
# Out:
# 2000/2000 [==============================] - 7s 3ms/sample - loss: 2.1447 - categorical_accuracy: 0.1660
# 0.166
# 2000/2000 [==============================] - 7s 4ms/sample
# Test set classification report:
#
#               precision    recall  f1-score   support
#
#            2       0.57      0.35      0.43       207
#            4       0.14      0.46      0.22       170
#           10       0.17      0.14      0.15       218
#           15       0.22      0.07      0.10       197
#           20       0.11      0.17      0.13       201
#           30       0.14      0.01      0.03       204
#           40       0.12      0.12      0.12       188
#           60       0.11      0.22      0.15       208
#           80       0.36      0.02      0.04       210
#          100       0.17      0.14      0.15       197
#
#     accuracy                           0.17      2000
#    macro avg       0.21      0.17      0.15      2000
# weighted avg       0.21      0.17      0.15      2000

# %%
# need this to avoid callback errors
from sklearn.metrics import confusion_matrix
importlib.reload(dat)

# generate confusion matrix
cfm = confusion_matrix(output_ref_c, output_predict_c)  

# row normalisation of confusion matrix
cfm_probability = cfm.astype('float')/cfm.sum(axis=1)[:, np.newaxis]  
# confusion probability matrix
cfm_probability = cfm_probability * 100.0  

fig, ax = plt.subplots(1,1, figsize=(10,10))
dat.plotConfusionMatrix(ax, cfm_probability, output_class_names, 2)

# save figure
fig.savefig(save_image_dir+'/cfm_inter%s_epochs_%d.png'%(model_name, max_epochs))    
fig.tight_layout()
