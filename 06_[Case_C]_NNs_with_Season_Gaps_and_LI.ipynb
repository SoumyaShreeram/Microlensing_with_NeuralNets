# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaShreeram/Microlensing_with_NeuralNets/blob/master/06_%5BCase_C%5D_NNs_with_Season_Gaps_and_LI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## {**Case C**}  Deep learning using NNs with microlensing curves ***with Season Gaps and Linear Interpolation (LI)***
#
# The following notebook tests NNs on microlensed light curves that do not contain season gaps. The notebook contains the following sections:
# 1. Input parameters
# 2. Loading data <br>
#   i. Plotting light curves
# 3. Generations of training and testing data sets
# 4. Compiling the 3 networks (can choose one of them for training) <br>
#   i. CNN <br>
#   ii. ResNet-7 <br>
#   iii. ResNet-18
# 5. Training the network on the optimized parameters <br>
#   i. Plotting loss-accuracy curves <br>
#   ii. Displaying the confusioni matrix
#
#
# **Author**: Soumya Shreeram <br>
# **Script adapted from**: Millon Martin & Kevin Müller <br>
# **Date**: 23rd February 2020

# %% [markdown]
# Import all required python libraries

# %%
from google.colab import drive
import os
import pickle
import importlib
import itertools

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import random
import os
from IPython.display import Image, SVG

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from scipy.interpolate import interp1d 

# %tensorflow_version 1.x
import tensorflow as tf

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Activation, InputSpec
from tensorflow.python.keras.layers import Conv1D, Conv2D
from tensorflow.python.keras.layers import MaxPooling1D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Add, BatchNormalization, Concatenate
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Mount google drive

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Directory where the `python` files are stored on Google Drive. The `.py` files that are imported must be in the same working directory (nb stands for notebook). To reload the imported files - if you have made any changes to them - use `importlib.reload(short_name_for_the_imported_py_file); eg. dat or nnet` .

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks')

import nb_02i_preprocessing_data as dat
import nb_03_neural_network_designs as nnet

# %% [markdown]
# Setting up the path to the data directory

# %%
current_dir = os.getcwd()
data_dir = '/content/gdrive/My Drive/training_set_microlensing/'
save_image_dir = r'/content/gdrive/My Drive/Colab Notebooks/Images/'
save_model_dir = r'/content/gdrive/My Drive/Colab Notebooks/Models/'
save_data_dir = r'/content/gdrive/My Drive/Colab Notebooks/Data/'

# %% [markdown]
# ### 1. Input parameters
#
# The scale radius used here is in pixels, where 1 pixel = 0.67 $R_{\rm ref}$; $R_{\rm ref} = 0.048 \ R_{\rm E}$ is the reference radius for QSO $J0158$ that is borrowed from [Mosquera & Kochanek (2011)](https://iopscience.iop.org/article/10.1088/0004-637X/738/1/96/pdf).

# %%
v_t = [500, 300] # transverse velcity
v_t_idx = 0 # choose index value for the velocity you would like (0 or 1)
r_0 = (2,4,10,15,20,30,40,60,80,100) # scale radius
output_class_names = [str(r) for r in r_0 ]

# select type of Interpolation
cubic, linear = False, True

""""select the type of nnet's to use
old_version :: borrowed from Martin & Kevins code
modified_version :: some minor changes compared to previous version
"""
old_version, modified_version = True, False

# data loaded with season gaps
season_gaps = True

# if using the new data set generated by Eric
new_data_set = True

# generates new interpolated light curves? OR Use previously saved light curves?
generate_new_files, use_saved_file = False, True

# %% [markdown]
# If using the `new_data_set`, make sure to have the `numLcurvesPerRadius...npy` file in the `v_x00` folder. This file contains the *number of light curves per radius, total curves, number of samples, etc* such that one does not need to hard-code the parameters when opening the files, whose names contain such variable. See more details on how it is read in the imported file `nb_02i_preprocessing_data.py`.

# %% [markdown]
# ### 2. Load the data

# %% [markdown]
# There are 10 categories into which the light-curves are classified. Each category is represented by the scale radius `r_0`. The light-curves corresponding to each `r_0` are collectively stored in the 3D array `l_curves` whose shape corresponds to `= (num_features, num_samples, 1)`

# %%
# sets the sampling parameters
sample_params = dat.setSamplingParameters(v_t[v_t_idx], data_dir, season_gaps)

# initializes data arrays
class_cat, l_curves, out_catergories, out_radii = dat.initializer(r_0, \
                                                                  sample_params)

for idx, rad in enumerate(r_0):
  filename = dat.getFilename(data_dir, idx, rad, v_t[v_t_idx], sample_params, \
                             season_gaps, new_data_set)
  
  # load data from the file
  l_curves, _, _ = dat.loadData(filename, idx, l_curves, sample_params, idx,\
                                  season_gaps, new_data_set)
  out_catergories[idx*sample_params[0][idx]:(idx+1)*sample_params[0][idx]] = class_cat[1][idx]
  out_radii[idx*sample_params[0][idx]:(idx+1)*sample_params[0][idx]] = r_0[idx]

print('Shape of light curves vector:', np.shape(l_curves))
# Out:
# Shape of light curves vector: (50000, 955, 1)

# %% [markdown]
# #### 2.1 Interpolation of the light curves

# %%
def interpolateLCurves(l_curves, mjhd, l_curves_interpolated, type_inter='linear'):
  """
  Function for interpolating the light curves 'linearly'
  @l_curves :: non-interpolated light curves 3Darray
  @l_curves_interpolated :: empty array with shape same as l_curves

  @Returns:: linearly interpolated light curves 3Darray
  """
  for i in range(len(l_curves)):
    # x array of times
    x = mjhd
    y = l_curves[i, :, 0]
    
    # interpolation
    f = interp1d(x,y, kind=type_inter)
    
    # capturing the features using y_inter
    xnew = np.linspace(x[0], x[-1], num=len(mjhd))
    y_inter = f(xnew)

    # setting the shape same as that on l_curves array
    y_inter.shape = (len(y_inter), 1)
    l_curves_interpolated = np.append(l_curves_interpolated, [y_inter], axis=0)
  return l_curves_interpolated, xnew

# %% [markdown]
# Linear and cubic interpolation were tested and it was found that the linear interpolation well approcimated the gaps. Cubic interpolation exaggerated the features in the gaps.

# %%
# initializing a light curve array to store the interpolated curves
l_curves_interpolated = np.array([])
l_curves_interpolated.shape = (0, len(l_curves[0,:,0]),1)

# time array loaded from a file
mjhd = np.load(data_dir+'Light_Curves/mjhd.npy')

if generate_new_files:
  # linear/cubic interpolated the light curves
  if linear:
    lc_inter_linear, mjhd_inter = interpolateLCurves(l_curves, mjhd, l_curves_interpolated, \
                                        type_inter='linear')
    
  if cubic:
    lc_inter_cubic, mjhd_inter = interpolateLCurves(l_curves, mjhd, l_curves_interpolated, \
                                        type_inter='cubic')

# %% [markdown]
# Saves the light curve arrays

# %%
if generate_new_files:  
  dat.saveFile(data_dir, 'Light_Curves/lcurves_SeasonGaps_LinearInter_%d'%len(lc_inter_linear), lc_inter_linear)
  dat.saveFile(data_dir, 'Light_Curves/mjhd_inter', mjhd_inter)

  # prints the light curves array shape
  dat.printLcurvesShape(lc_inter_linear)

# %% [markdown]
# Loads the ligths arrays (if not generated again)

# %%
if use_saved_file:
  lc_inter_linear = dat.loadFile(data_dir, \
                                 'Light_Curves/lcurves_SeasonGaps_LinearInter_%d'%len(l_curves))
  mjhd_inter = dat.loadFile(data_dir, 'Light_Curves/mjhd_inter')
  
  # prints the light curves shape
  dat.printLcurvesShape(lc_inter_linear)
# Out:
# shape of light curves arrays: (50000, 955, 1)

# %% [markdown]
# #### 2.1 Plots of some random light-curves

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
n = [9900, 2600]
colors = ['#7bdbaa',  '#8b88eb', '#888894']

mjhd = np.load(data_dir+'Light_Curves/mjhd.npy')

for i, num in enumerate(n):
  # light curves with cubic interpolation
  if cubic:
    ax.plot(mjhd_inter, lc_inter_cubic[n[i], :, 0], '.', color='r', label='Cubic interpolation', markersize=4)

  # light curves with linear interpolation
  ax.plot(mjhd_inter, lc_inter_linear[n[i], :, 0], '.', color='k', markersize=2)

  # without interpolation
  ax.plot(mjhd, l_curves[n[i], :], '.', color=colors[i], label='Radius: %i'%(out_radii[n[i]]), markersize=8)

dat.setLabels(ax, 'HJD (days)', 'Magnitude', ticks=True, legend=True)
fig.savefig(save_image_dir+'/interpolated_lcurves.png') 

print(out_radii[9900], out_radii[2600])
# Out:
# 4.0 2.0

# %% [markdown]
# ### 3. Generate training and testing data sets
#
# Proceeding with linear interpolation.

# %%
train_l_curves, test_l_curves, onehot_train, onehot_test, train_radii, \
test_radii  = dat.generateTestTrain(lc_inter_linear, out_catergories, out_radii, r_0)

trainX, trainy, testX, testy = train_l_curves, onehot_train, test_l_curves, onehot_test

# %% [markdown]
# ### 4. Compiling the 3 networks
#
# The three networks compiled here are coded in `nb04_Neural_Network_Designs.py`. These `.py` files can be found in the GitHub repository.
#
# Note that if you are running this from colab, need to have these `.py` files in your drive folder *Colab Notebooks*.
#
# The three networks are the Convolutional Neural Network (**CNN**), Residual Neural Network with 7 layers (**ResNet7**), and the Residual Neural Network with 18 layers (**ResNet18**). Refer to the report for more detailed information about the neural network stuctures.

# %%
# choose one of these networks to use by setting the boolean to True and rest to False
CNN, ResNet7, ResNet18 = False, True, False

model_types = [CNN, ResNet7, ResNet18]
model_name_list = ['CNN','ResNet7', 'ResNet18']

for i in range(len(model_name_list)):
  if model_types[i]:
    model_name = model_name_list[i]
print('Using the Neural Network:', model_name)
# Out:
# Using the Neural Network: ResNet7

# %% [markdown]
# The following code block uses the methods defined in the file `dr04_Neural_Network_Designs.py`: imported as **`nnet`**
#
# Model parameters are defined in the methods in **`nnet`** additionally some more details:
# * `num_hidden_nodes`: number of nodes in hidden fully connected layer
# *`dropout_ratio`: % of nodes in the hidden layer to dropout during back-propagation update of the network weights

# %% [markdown]
# #### 4.1 Compiling CNN

# %%
if CNN:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  # CNN model parameters
  num_filter = (32, 32, 44, 44)
  kern_size = (21,21,15,15)
  maxpoolsize = (None, 15, None, 15)
  shortcut_link = (0,1,2,3)
  batch_norm = False
  dropout_ratio = 0.4  
  sampling = 3
  num_pieces = 1
  num_hidden_nodes = 1500
  
  # build the model
  inputs, outputs = nnet.buildCNN(sample_params[2], num_filter, kern_size, maxpoolsize, \
                                  num_hidden_nodes, dropout_ratio, r_0)
  
  # optimization, compilation parameters
  optimizer_type = Adam(lr=5e-4)  
  loss = 'categorical_crossentropy'  
  metrics = ['categorical_accuracy'] 

  # compiles the model
  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                    metrics, save_image_dir+'CNN', True)
    
  print('Network created')

# %% [markdown]
# #### 4.2 Compiling ResNet-7

# %%
if ResNet7:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  # CNN model parameters
  num_filter = (32, 32, 44, 44)
  kern_size = (21,21,15,15)
  maxpoolsize = (None, 15, None, 15)
  shortcut_link = (0,1,2,3)
  batch_norm = False
  dropout_ratio = 0.4  
  sampling = 3
  num_pieces = 1
  num_hidden_nodes = [1500]
  
  # prepare data with sample cuts with the correct shape
  testX_prep = nnet.prepareDataSampleCuts(testX, sampling, num_pieces)
  trainX_prep = nnet.prepareDataSampleCuts(trainX, sampling, num_pieces)

  # build the model
  inputs, outputs = nnet.buildResNet7(num_filter, kern_size, \
                                                  maxpoolsize, num_hidden_nodes[0], \
                                                  dropout_ratio, shortcut_link, \
                                                  batch_norm, trainX_prep.shape[1], r_0)
  
  # optimization, compilation parameters
  optimizer_type = Adam(lr=5e-4)  
  loss = 'categorical_crossentropy'  
  metrics = ['categorical_accuracy'] 

  # compiles the model
  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                    metrics, save_image_dir+'ResNet-7', do_print_summary = False)
    
  print('Network created')

# %% [markdown]
# ### 4.3 Compiling ResNet-18

# %%
if ResNet18:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  # ResNet model parameters
  num_filter = (32, 32, 32)
  kern_size = (10,20,50)
  n_block = 5
  maxpoolsize = 3
  num_hidden_nodes =[1000.0,]
  dropout_ratio = 0.7 
  batch_norm = True
  sampling = 1
  num_pieces = 1

  # build network
  inputs, outputs = nnet.buildResNet18(sample_params[2], num_filter, kern_size, n_block, \
                                 maxpoolsize, num_hidden_nodes, dropout_ratio, r_0,\
                                 batch_norm)
  
  # ResNet compilation parameters
  learning_rate = 1e-4
  max_epochs = 80
  decay = learning_rate/max_epochs
  optimizer_type = Adam(lr=learning_rate, decay=decay)  
  loss = 'categorical_crossentropy'  
  metrics = ['categorical_accuracy'] 

  # compiles network
  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                     metrics,save_image_dir+'ResNet-18', True)
  
  #model.load_weights('/content/gdrive/My Drive/Colab_Notebooks/Deep_learning_for_optical_IMaging/Resnet_weights.h5')
  print('Network created')

# %% [markdown]
# ### 5. Training the network
#
# Constants used for training the network

# %%
validation_split_ratio = 0.2  # % of the seen dataset to be put aside for validation, rest is for training
max_epochs = 50  # maxmimum number of epochs to be iterated
batch_size = 60   # batch size for the training data set
num_inputs = 1
verbose = 1

# %%
if ResNet7:
  # reshaped data is used while training
  trainX = trainX_prep
  testX = testX_prep

# trains the model
model, model_history = nnet.trainModel(model, trainX, trainy, batch_size, max_epochs,\
                                  validation_split_ratio, verbose)

# evaluates and predicts the results from the trained model
results, predictions = nnet.evaluatePredictModel(model, testX, testy, verbose = 1) 

print('[test loss, test acc] = ', results)
# Out:
# Train on 32000 samples, validate on 8000 samples
# Epoch 1/50
# 32000/32000 [==============================] - 12s 368us/sample - loss: 1.8865 - categorical_accuracy: 0.2665 - val_loss: 1.6349 - val_categorical_accuracy: 0.3550
# Epoch 2/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.6020 - categorical_accuracy: 0.3807 - val_loss: 1.5029 - val_categorical_accuracy: 0.4198
# Epoch 3/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.4529 - categorical_accuracy: 0.4448 - val_loss: 1.3849 - val_categorical_accuracy: 0.4744
# Epoch 4/50
# 32000/32000 [==============================] - 6s 172us/sample - loss: 1.3658 - categorical_accuracy: 0.4774 - val_loss: 1.3145 - val_categorical_accuracy: 0.4991
# Epoch 5/50
# 32000/32000 [==============================] - 6s 175us/sample - loss: 1.2905 - categorical_accuracy: 0.5025 - val_loss: 1.2599 - val_categorical_accuracy: 0.5176
# Epoch 6/50
# 32000/32000 [==============================] - 6s 180us/sample - loss: 1.2291 - categorical_accuracy: 0.5212 - val_loss: 1.2253 - val_categorical_accuracy: 0.5263
# Epoch 7/50
# 32000/32000 [==============================] - 6s 176us/sample - loss: 1.1867 - categorical_accuracy: 0.5366 - val_loss: 1.2073 - val_categorical_accuracy: 0.5226
# Epoch 8/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.1484 - categorical_accuracy: 0.5499 - val_loss: 1.1331 - val_categorical_accuracy: 0.5485
# Epoch 9/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.1080 - categorical_accuracy: 0.5648 - val_loss: 1.1512 - val_categorical_accuracy: 0.5530
# Epoch 10/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.0866 - categorical_accuracy: 0.5732 - val_loss: 1.0841 - val_categorical_accuracy: 0.5748
# Epoch 11/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.0567 - categorical_accuracy: 0.5847 - val_loss: 1.0963 - val_categorical_accuracy: 0.5683
# Epoch 12/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.0443 - categorical_accuracy: 0.5872 - val_loss: 1.0554 - val_categorical_accuracy: 0.5790
# Epoch 13/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.0229 - categorical_accuracy: 0.5928 - val_loss: 1.0339 - val_categorical_accuracy: 0.5920
# Epoch 14/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 1.0042 - categorical_accuracy: 0.5989 - val_loss: 1.0576 - val_categorical_accuracy: 0.5770
# Epoch 15/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 0.9874 - categorical_accuracy: 0.6080 - val_loss: 1.0392 - val_categorical_accuracy: 0.5886
# Epoch 16/50
# 32000/32000 [==============================] - 6s 172us/sample - loss: 0.9759 - categorical_accuracy: 0.6130 - val_loss: 1.0376 - val_categorical_accuracy: 0.5897
# Epoch 17/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.9608 - categorical_accuracy: 0.6177 - val_loss: 1.0239 - val_categorical_accuracy: 0.5934
# Epoch 18/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.9467 - categorical_accuracy: 0.6219 - val_loss: 0.9945 - val_categorical_accuracy: 0.5970
# Epoch 19/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 0.9334 - categorical_accuracy: 0.6263 - val_loss: 1.0031 - val_categorical_accuracy: 0.6061
# Epoch 20/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 0.9165 - categorical_accuracy: 0.6342 - val_loss: 0.9762 - val_categorical_accuracy: 0.6090
# Epoch 21/50
# 32000/32000 [==============================] - 6s 172us/sample - loss: 0.9107 - categorical_accuracy: 0.6376 - val_loss: 0.9771 - val_categorical_accuracy: 0.6140
# Epoch 22/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.8978 - categorical_accuracy: 0.6399 - val_loss: 0.9587 - val_categorical_accuracy: 0.6144
# Epoch 23/50
# 32000/32000 [==============================] - 6s 172us/sample - loss: 0.8848 - categorical_accuracy: 0.6435 - val_loss: 0.9766 - val_categorical_accuracy: 0.6085
# Epoch 24/50
# 32000/32000 [==============================] - 6s 174us/sample - loss: 0.8763 - categorical_accuracy: 0.6493 - val_loss: 0.9739 - val_categorical_accuracy: 0.6095
# Epoch 25/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 0.8675 - categorical_accuracy: 0.6529 - val_loss: 0.9657 - val_categorical_accuracy: 0.6158
# Epoch 26/50
# 32000/32000 [==============================] - 6s 172us/sample - loss: 0.8494 - categorical_accuracy: 0.6599 - val_loss: 0.9619 - val_categorical_accuracy: 0.6169
# Epoch 27/50
# 32000/32000 [==============================] - 6s 172us/sample - loss: 0.8575 - categorical_accuracy: 0.6547 - val_loss: 0.9559 - val_categorical_accuracy: 0.6145
# Epoch 28/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.8426 - categorical_accuracy: 0.6614 - val_loss: 0.9471 - val_categorical_accuracy: 0.6229
# Epoch 29/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.8307 - categorical_accuracy: 0.6653 - val_loss: 0.9413 - val_categorical_accuracy: 0.6214
# Epoch 30/50
# 32000/32000 [==============================] - 6s 174us/sample - loss: 0.8287 - categorical_accuracy: 0.6672 - val_loss: 0.9612 - val_categorical_accuracy: 0.6208
# Epoch 31/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.8152 - categorical_accuracy: 0.6717 - val_loss: 0.9326 - val_categorical_accuracy: 0.6324
# Epoch 32/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.8089 - categorical_accuracy: 0.6714 - val_loss: 0.9416 - val_categorical_accuracy: 0.6237
# Epoch 33/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.8035 - categorical_accuracy: 0.6779 - val_loss: 0.9596 - val_categorical_accuracy: 0.6179
# Epoch 34/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.7984 - categorical_accuracy: 0.6797 - val_loss: 0.9789 - val_categorical_accuracy: 0.6108
# Epoch 35/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.7911 - categorical_accuracy: 0.6813 - val_loss: 0.9163 - val_categorical_accuracy: 0.6382
# Epoch 36/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.7819 - categorical_accuracy: 0.6850 - val_loss: 0.9320 - val_categorical_accuracy: 0.6339
# Epoch 37/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.7723 - categorical_accuracy: 0.6885 - val_loss: 0.9354 - val_categorical_accuracy: 0.6244
# Epoch 38/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.7633 - categorical_accuracy: 0.6954 - val_loss: 0.9483 - val_categorical_accuracy: 0.6289
# Epoch 39/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.7618 - categorical_accuracy: 0.6922 - val_loss: 0.9159 - val_categorical_accuracy: 0.6423
# Epoch 40/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.7540 - categorical_accuracy: 0.6928 - val_loss: 0.9441 - val_categorical_accuracy: 0.6317
# Epoch 41/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.7527 - categorical_accuracy: 0.6977 - val_loss: 0.9289 - val_categorical_accuracy: 0.6366
# Epoch 42/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.7462 - categorical_accuracy: 0.6981 - val_loss: 0.9579 - val_categorical_accuracy: 0.6308
# Epoch 43/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.7416 - categorical_accuracy: 0.7002 - val_loss: 0.9515 - val_categorical_accuracy: 0.6286
# Epoch 44/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.7331 - categorical_accuracy: 0.7051 - val_loss: 0.9401 - val_categorical_accuracy: 0.6336
# Epoch 45/50
# 32000/32000 [==============================] - 5s 171us/sample - loss: 0.7255 - categorical_accuracy: 0.7055 - val_loss: 0.9461 - val_categorical_accuracy: 0.6423
# Epoch 46/50
# 32000/32000 [==============================] - 5s 172us/sample - loss: 0.7254 - categorical_accuracy: 0.7067 - val_loss: 0.9223 - val_categorical_accuracy: 0.6435
# Epoch 47/50
# 32000/32000 [==============================] - 6s 173us/sample - loss: 0.7105 - categorical_accuracy: 0.7113 - val_loss: 0.9556 - val_categorical_accuracy: 0.6356
# Epoch 48/50
# 32000/32000 [==============================] - 6s 176us/sample - loss: 0.7130 - categorical_accuracy: 0.7112 - val_loss: 0.9643 - val_categorical_accuracy: 0.6356
# Epoch 49/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.7058 - categorical_accuracy: 0.7167 - val_loss: 0.9247 - val_categorical_accuracy: 0.6453
# Epoch 50/50
# 32000/32000 [==============================] - 5s 170us/sample - loss: 0.7015 - categorical_accuracy: 0.7167 - val_loss: 0.9331 - val_categorical_accuracy: 0.6438
# 10000/10000 [==============================] - 1s 109us/sample - loss: 0.9561 - categorical_accuracy: 0.6339
# 10000/10000 [==============================] - 1s 74us/sample
# [test loss, test acc] =  [0.956053489780426, 0.6339]

# %%
# plots the history
fig, ax = plt.subplots(1,2, figsize=(14,6))
labels = ['training', 'validation']
loss_Accuracy = ['loss', 'val_loss', 'categorical_accuracy', 'val_categorical_accuracy']

model_history = model_history.history
dat.plotLoss(ax[0], model_history, loss_Accuracy, model_name, labels)
dat.plotAccuracy(ax[1], model_history, loss_Accuracy, model_name, labels)
 
fig.savefig(save_image_dir+'/LandA_inter%s_epochs_%d.png'%(model_name, max_epochs))    
fig.tight_layout()

# %%
data = [model_history[loss_Accuracy[0]], model_history[loss_Accuracy[1]], \
        model_history[loss_Accuracy[2]], model_history[loss_Accuracy[3]]]

# saves the loss and accuracy curves
filename = save_data_dir+'SeasonGaps_LI_%s.npy'%model_name
with open(filename, 'wb') as f:
  np.save(f, data, allow_pickle=True)

# %% [markdown]
# ### 6. Displaying the classification report, confusion matrix

# %%
y_predict = np.argmax(predictions, axis=1)
y_test = np.argmax(testy, axis=1)

print('Test set classification report:\n')
print(classification_report(y_test, y_predict, target_names=output_class_names))
# Out:
# Test set classification report:
#
#               precision    recall  f1-score   support
#
#            2       0.87      0.88      0.87      1001
#            4       0.82      0.79      0.80       992
#           10       0.79      0.73      0.76      1019
#           15       0.72      0.59      0.65       983
#           20       0.64      0.74      0.69       982
#           30       0.55      0.52      0.54       981
#           40       0.61      0.57      0.59      1048
#           60       0.53      0.73      0.61      1019
#           80       0.41      0.42      0.42      1026
#          100       0.44      0.36      0.39       949
#
#     accuracy                           0.63     10000
#    macro avg       0.64      0.63      0.63     10000
# weighted avg       0.64      0.63      0.63     10000

# %%
# need this to avoid callback errors
from sklearn.metrics import confusion_matrix
importlib.reload(dat)

# generate confusion matrix
cfm = confusion_matrix(y_test, y_predict)  

# row normalisation of confusion matrix
cfm_probability = cfm.astype('float')/cfm.sum(axis=1)[:, np.newaxis]  
# confusion probability matrix
cfm_probability = cfm_probability * 100.0  

fig, ax = plt.subplots(1,1, figsize=(10,10))
dat.plotConfusionMatrix(ax, cfm_probability, output_class_names, 2)

# save figure
fig.savefig(save_image_dir+'/cfm_%s_epochs_%d_noInter.png'%(model_name, max_epochs))    
fig.tight_layout()
